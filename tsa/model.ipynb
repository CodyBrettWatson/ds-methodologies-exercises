# %%
import pandas as pd

# %%
import csv

with open('access.log') as file:
    lines = file.read().splitlines()
    lines = [lines[x:x+1] for x in range(0, len(lines), 3)]

    with open('access_log2.csv', 'w+') as csvfile:
        w = csv.writer(csvfile)
        w.writerows(lines)
    
with open ('./access.log') as f:
           contents = f.read()
lines = contents.splitlines()
line = lines[0]
line.split(' ')

# %%
df = pd.read_csv('access_log.csv', sep='\t')

# %%
df
# Out:
#      97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] "GET /api/v1/sales?page=81 HTTP/1.1" 200 512495 "-" "python-requests/2.21.0","97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] ""GET /api/v1/items HTTP/1.1"" 200 3561 ""-"" ""python-requests/2.21.0""","97.105.19.58 - - [16/Apr/2019:19:34:44 +0000] ""GET /api/v1/sales?page=82 HTTP/1.1"" 200 510103 ""-"" ""python-requests/2.21.0"""
# 0     97.105.19.58 - - [16/Apr/2019:19:34:46 +0000] ...
# 1     97.105.19.58 - - [16/Apr/2019:19:34:50 +0000] ...
# 2     97.105.19.58 - - [16/Apr/2019:19:34:53 +0000] ...
# 3     97.105.19.58 - - [16/Apr/2019:19:34:54 +0000] ...
# 4     97.105.19.58 - - [16/Apr/2019:19:34:58 +0000] ...
# 5     97.105.19.58 - - [16/Apr/2019:19:35:05 +0000] ...
# 6     97.105.19.58 - - [16/Apr/2019:19:35:10 +0000] ...
# 7     97.105.19.58 - - [16/Apr/2019:19:35:16 +0000] ...
# 8     97.105.19.58 - - [16/Apr/2019:19:35:22 +0000] ...
# 9     97.105.19.58 - - [16/Apr/2019:19:35:28 +0000] ...
# ...

# %%
# df.columns = ['ip', 'date_time', 'get','http_status_code', '-','content_length', 'user_agent']

# %%
97.105.19.58 - - 
[16/Apr/2019:22:00:58 +0000] 
"GET /api/v1/sales?page=175 HTTP/1.1" 
200 
510539 
"-" 
"python-requests/2.21.0"


"97.105.19.58 - - 
[16/Apr/2019:21:52:44 +0000] 
""GET /api/v1/sales?page=111 HTTP/1.1"" 
200 
510472 
""-"" 
""python-requests/2.21.0"""

# %%
with open ('./access.log') as f:
           contents = f.read()
lines = contents.splitlines()
line = lines[0]
lineone = line.split(' ')

# %%
lineone
# Out:
# ['97.105.19.58',
#  '-',
#  '-',
#  '[16/Apr/2019:19:34:42',
#  '+0000]',
#  '"GET',
#  '/api/v1/sales?page=81',
#  'HTTP/1.1"',
#  '200',
#  '512495',
#  '"-"',
#  '"python-requests/2.21.0"']

# %%
test = pd.DataFrame([lineone])

# %%
test
# Out:
#              0  1  2                      3       4     5   \
# 0  97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]  "GET
#
#                       6          7    8       9    10  \
# 0  /api/v1/sales?page=81  HTTP/1.1"  200  512495  "-"
#
#                          11
# 0  "python-requests/2.21.0"

# %%
test.columns = ['ip','drop1','drop2', 'date_time','addbackDT', 'get','addbackGET1','addbackGET2','http_status_code','content_length', 'drop3', 'user_agent']

# %%
test
# Out:
#              ip drop1 drop2              date_time addbackDT   get  \
# 0  97.105.19.58     -     -  [16/Apr/2019:19:34:42    +0000]  "GET
#
#              addbackGET1 addbackGET2 http_status_code content_length drop3  \
# 0  /api/v1/sales?page=81   HTTP/1.1"              200         512495   "-"
#
#                  user_agent
# 0  "python-requests/2.21.0"

# %%
test.drop(['drop1', 'drop2', 'drop3'], axis=1, inplace=True)

# %%
test
# Out:
#              ip              date_time addbackDT   get            addbackGET1  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42    +0000]  "GET  /api/v1/sales?page=81
#
#   addbackGET2 http_status_code content_length                user_agent
# 0   HTTP/1.1"              200         512495  "python-requests/2.21.0"

# %%
test.replace(to_replace='"', value='', regex=True)
# Out:
#              ip              date_time addbackDT  get            addbackGET1  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42    +0000]  GET  /api/v1/sales?page=81
#
#   addbackGET2 http_status_code content_length              user_agent
# 0    HTTP/1.1              200         512495  python-requests/2.21.0

# %%
test['date_time_full'] = test['date_time'].map(str) + ' ' + test['addbackDT']

# %%
test
# Out:
#              ip              date_time addbackDT   get            addbackGET1  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42    +0000]  "GET  /api/v1/sales?page=81
#
#   addbackGET2 http_status_code content_length                user_agent  \
# 0   HTTP/1.1"              200         512495  "python-requests/2.21.0"
#
#                  date_time_full
# 0  [16/Apr/2019:19:34:42 +0000]

# %%
test['get_full'] = test['get'].map(str) + ' ' + test['addbackGET1'] + ' ' + test['addbackGET2']

# %%
test
# Out:
#              ip              date_time addbackDT   get            addbackGET1  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42    +0000]  "GET  /api/v1/sales?page=81
#
#   addbackGET2 http_status_code content_length                user_agent  \
# 0   HTTP/1.1"              200         512495  "python-requests/2.21.0"
#
#                  date_time_full                              get_full
# 0  [16/Apr/2019:19:34:42 +0000]  "GET /api/v1/sales?page=81 HTTP/1.1"

# %%
test.columns
# Out:
# Index(['ip', 'date_time', 'addbackDT', 'get', 'addbackGET1', 'addbackGET2',
#        'http_status_code', 'content_length', 'user_agent', 'date_time_full',
#        'get_full'],
#       dtype='object')

# %%
test.drop(['date_time', 'addbackDT', 'get', 'addbackGET1', 'addbackGET2',], axis=1, inplace=True)

# %%
test
# Out:
#              ip http_status_code content_length                user_agent  \
# 0  97.105.19.58              200         512495  "python-requests/2.21.0"
#
#                  date_time_full                              get_full
# 0  [16/Apr/2019:19:34:42 +0000]  "GET /api/v1/sales?page=81 HTTP/1.1"

# %%
test = test.reindex(columns=['ip','date_time_full','get_full','http_status_code', 'content_length', 'user_agent'])

# %%
test
# Out:
#              ip                date_time_full  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
#
#                                get_full http_status_code content_length  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"              200         512495
#
#                  user_agent
# 0  "python-requests/2.21.0"

# %%
test.replace(to_replace='"', value='', regex=True, inplace=True)

# %%
test
# Out:
#              ip                date_time_full  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
#
#                              get_full http_status_code content_length  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1              200         512495
#
#                user_agent
# 0  python-requests/2.21.0

# %%
import csv

# with open('access.log') as file:
#     lines = file.read().splitlines()
#     lines = [lines[x:x+1] for x in range(0, len(lines), 3)]

#     with open('access_log2.csv', 'w+') as csvfile:
#         w = csv.writer(csvfile)
#         w.writerows(lines)

with open ('./access.log') as f:
           contents = f.read()
lines = contents.splitlines()
line = lines[:]
all_lines = line.split(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-6df515646427> in <module>
#      13 lines = contents.splitlines()
#      14 line = lines[:]
# ---> 15 all_lines = line.split(' ')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
test = pd.DataFrame([all_lines])

# %%
test
# Out:
#              0  1  2                      3       4     5   \
# 0  97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]  "GET
#
#                       6          7    8       9    10  \
# 0  /api/v1/sales?page=81  HTTP/1.1"  200  512495  "-"
#
#                          11
# 0  "python-requests/2.21.0"

# %%
with open('./access.log') as f:
    contents = f.read()

# %%
lines = contents.split('\n')

# %%
line = lines[0]

# %%
line.split(' ')
# Out:
# ['97.105.19.58',
#  '-',
#  '-',
#  '[16/Apr/2019:19:34:42',
#  '+0000]',
#  '"GET',
#  '/api/v1/sales?page=81',
#  'HTTP/1.1"',
#  '200',
#  '512495',
#  '"-"',
#  '"python-requests/2.21.0"']

# %%
with open('./access.log') as f:
    contents = f.read()

# %%
lines = contents.split('\n')

# %%
line=lines[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6663bdcaf442> in <module>
# ----> 1 line=lines[0]
#
# NameError: name 'lines' is not defined

# %%
def process_line(line: str):
    parts = line.split(' ')
    for i, part in enumerate(parts):
        print(i, part)

# %%
def process_line(line: str):
    parts = line.split(' ')

    ip = parts[0]

    timestamp = parts[3] + parts[4]
    timestamp = timestamp.replace('[', '')
    timestamp = timestamp.replace(']', '')

    request_method = parts[5]
    request_method = request_method.replace('"', '')

    path = parts[6]
    protocol_version = parts[7]
    protocol_version = protocol_version.replace('"', '')
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    unknown = unknown.replace('"', '')
    user_agent = parts[11]
    user_agent = user_agent.replace('"', '')

    return dict(ip=ip, timestamp=timestamp,
                method=request_method,
                path=path,
                protocol=protocol_version,
                code=status_code,
                size=size,
                unknown=unknown,
                user_agent=user_agent)

# %%
process_line(lines[0])
# Out:
# {'ip': '97.105.19.58',
#  'timestamp': '16/Apr/2019:19:34:42+0000',
#  'method': 'GET',
#  'path': '/api/v1/sales?page=81',
#  'protocol': 'HTTP/1.1',
#  'code': '200',
#  'size': '512495',
#  'unknown': '-',
#  'user_agent': 'python-requests/2.21.0'}

# %%
lines = lines[:-1]
processed_lines = []
for line in lines:
    processed_lines.append(process_line(line))

# %%
lines
# Out:
# ['97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] "GET /api/v1/sales?page=81 HTTP/1.1" 200 512495 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:42 +0000] "GET /api/v1/items HTTP/1.1" 200 3561 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:44 +0000] "GET /api/v1/sales?page=82 HTTP/1.1" 200 510103 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:46 +0000] "GET /api/v1/sales?page=83 HTTP/1.1" 200 510003 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:48 +0000] "GET /api/v1/sales?page=84 HTTP/1.1" 200 511963 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:48 +0000] "GET /api/v1/stores HTTP/1.1" 200 1328 "-" "python-requests/2.21.0"',
#  '97.105.19.58 - - [16/Apr/2019:19:34:50 +0000] "GET /api/v1/sales?page=85 HTTP/1.1" 200 510753 "-" "python-requests/2.21.0"',
# ...

# %%
with open('./access.log') as f:
    contents = f.read()

type(contents)
contents
len(contents)
len('abc')
lines = contents.split('\n')
type(lines), type(lines[0])
line = lines[0]
line
line.split(' ')
# split the line on the space, identify the relevant parts, and discard anythin irrelevant
def process_line(line: str):
    parts = line.split(' ')
    for i, part in enumerate(parts):
        print(i, part)

process_line(line[0])
line[0]
lines[0]
process_line(lines[0])
def process_line(line: str):
    parts = line.split(' ')
    ip = parts[0]
    timestamp = parts[3] + parts[4]
    request_method = parts[5]
    path = parts[6]
    protocol_version = parts[7]
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    user_agent = parts[11]

def process_line(line: str):
    parts = line.split(' ')
    ip = parts[0]
    timestamp = parts[3] + parts[4]
    request_method = parts[5]
    path = parts[6]
    protocol_version = parts[7]
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    user_agent = parts[11]
    return dict(ip=ip, timestamp=timestamp,
                method=request_method,
                path=path,
                protocol=protocol_version,
                code=status_code,
                size=size,
                unknown=unknown,
                user_agent=user_agent)

process_line(lines[0])
def process_line(line: str):
    parts = line.split(' ')

    ip = parts[0]

    timestamp = parts[3] + parts[4]
    timestamp = timestamp.replace('[', '')
    timestamp = timestamp.replace(']', '')

    request_method = parts[5]
    request_method = request_method.replace('"', '')

    path = parts[6]
    protocol_version = parts[7]
    protocol_version = protocol_version.replace('"', '')
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    unknown = unknown.replace('"', '')
    user_agent = parts[11]
    user_agent = user_agent.replace('"', '')

    return dict(ip=ip, timestamp=timestamp,
                method=request_method,
                path=path,
                protocol=protocol_version,
                code=status_code,
                size=size,
                unknown=unknown,
                user_agent=user_agent)

process_line(lines[0])
process_line(lines[9])
process_line(lines[126])
len(lines)
process_line(lines[13972])
process_line(lines[13975])
process_line(lines[13974])
lines[13974]
lines[-4:-1]
lines[-1]
lines
lines[-1]
lines = lines[:-1]
processed_lines = []
for line in lines:
    processed_lines.append(process_line(line))

processed_lines[123:126]
make_into_dataframe(processed_lines)
import pandas as pd
df = pd.DataFrame(processed_lines)
df.head()
df.head()

# %%
with open('./access.log') as f:
    contents = f.read()

# %%
lines = contents.split('\n')

# %%
def process_line(line: str):
    parts = line.split(' ')

    ip = parts[0]

    timestamp = parts[3] + parts[4]
    timestamp = timestamp.replace('[', '')
    timestamp = timestamp.replace(']', '')

    request_method = parts[5]
    request_method = request_method.replace('"', '')

    path = parts[6]
    protocol_version = parts[7]
    protocol_version = protocol_version.replace('"', '')
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    unknown = unknown.replace('"', '')
    user_agent = parts[11:]
    user_agent = ' '.join(user_agent)
    user_agent = user_agent.replace('"', '')

    return dict(ip=ip, timestamp=timestamp,
                method=request_method,
                path=path,
                protocol=protocol_version,
                code=status_code,
                size=size,
                unknown=unknown,
                user_agent=user_agent)

# %%
lines = lines[:-1]
processed_lines = []
for line in lines:
    processed_lines.append(process_line(line))

# %%
import pandas as pd
df = pd.DataFrame(processed_lines)

# %% [markdown]
# # 1. make sure timestamp is a datetime type (Hint: pd.to_datetime)
# # 2. What does the unknown column mean?
# # 3. What do you make of the user_agent data?
# # 4. How many unique ip addresses are there? What does this mean? What is the most frequentip? What does this mean?

# %%
df.head()
# Out:
#   code            ip method                   path  protocol    size  \
# 0  200  97.105.19.58    GET  /api/v1/sales?page=81  HTTP/1.1  512495
# 1  200  97.105.19.58    GET          /api/v1/items  HTTP/1.1    3561
# 2  200  97.105.19.58    GET  /api/v1/sales?page=82  HTTP/1.1  510103
# 3  200  97.105.19.58    GET  /api/v1/sales?page=83  HTTP/1.1  510003
# 4  200  97.105.19.58    GET  /api/v1/sales?page=84  HTTP/1.1  511963
#
#                    timestamp unknown              user_agent
# 0  16/Apr/2019:19:34:42+0000       -  python-requests/2.21.0
# 1  16/Apr/2019:19:34:42+0000       -  python-requests/2.21.0
# 2  16/Apr/2019:19:34:44+0000       -  python-requests/2.21.0
# 3  16/Apr/2019:19:34:46+0000       -  python-requests/2.21.0
# 4  16/Apr/2019:19:34:48+0000       -  python-requests/2.21.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13972 entries, 0 to 13971
# Data columns (total 9 columns):
# code          13972 non-null object
# ip            13972 non-null object
# method        13972 non-null object
# path          13972 non-null object
# protocol      13972 non-null object
# size          13972 non-null object
# timestamp     13972 non-null object
# unknown       13972 non-null object
# user_agent    13972 non-null object
# dtypes: object(9)
# memory usage: 982.5+ KB

# %%
df.timestamp = df['timestamp'].str.replace(':',' ',1)

# %%
df.head()
# Out:
#   code            ip method                   path  protocol    size  \
# 0  200  97.105.19.58    GET  /api/v1/sales?page=81  HTTP/1.1  512495
# 1  200  97.105.19.58    GET          /api/v1/items  HTTP/1.1    3561
# 2  200  97.105.19.58    GET  /api/v1/sales?page=82  HTTP/1.1  510103
# 3  200  97.105.19.58    GET  /api/v1/sales?page=83  HTTP/1.1  510003
# 4  200  97.105.19.58    GET  /api/v1/sales?page=84  HTTP/1.1  511963
#
#                    timestamp unknown              user_agent
# 0  16/Apr/2019 19:34:42+0000       -  python-requests/2.21.0
# 1  16/Apr/2019 19:34:42+0000       -  python-requests/2.21.0
# 2  16/Apr/2019 19:34:44+0000       -  python-requests/2.21.0
# 3  16/Apr/2019 19:34:46+0000       -  python-requests/2.21.0
# 4  16/Apr/2019 19:34:48+0000       -  python-requests/2.21.0

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#   code            ip method                   path  protocol    size  \
# 0  200  97.105.19.58    GET  /api/v1/sales?page=81  HTTP/1.1  512495
# 1  200  97.105.19.58    GET          /api/v1/items  HTTP/1.1    3561
# 2  200  97.105.19.58    GET  /api/v1/sales?page=82  HTTP/1.1  510103
# 3  200  97.105.19.58    GET  /api/v1/sales?page=83  HTTP/1.1  510003
# 4  200  97.105.19.58    GET  /api/v1/sales?page=84  HTTP/1.1  511963
#
#             timestamp unknown              user_agent
# 0 2019-04-16 19:34:42       -  python-requests/2.21.0
# 1 2019-04-16 19:34:42       -  python-requests/2.21.0
# 2 2019-04-16 19:34:44       -  python-requests/2.21.0
# 3 2019-04-16 19:34:46       -  python-requests/2.21.0
# 4 2019-04-16 19:34:48       -  python-requests/2.21.0

# %%
df.unknown.unique()
# Out:
# array(['-', 'https://python.zach.lol/api/V1/HiZach!',
#        'https://python.zach.lol/api/v1/stores?page=0',
#        'https://python.zach.lol/api/v1/stores?page=1',
#        'https://python.zach.lol/api/v1/stores?page=2',
#        'https://python.zach.lol/api/v1/stores?page=999',
#        'https://python.zach.lol/api/v1/items?page=0',
#        'http://localhost:8889/notebooks/timeseries_acquisition.ipynb',
#        'https://python.zach.lol/api/v1//api/v1/items?page=2',
#        'https://python.zach.lol/api/v1//api/v1/items',
#        'https://python.zach.lol/api/v1//api/v1/items/next_page',
#        'https://python.zach.lol/api/v1/helloclass!',
#        'https://python.zach.lol/api/v1/I_DIDNT_DO_IT!!!!',
#        'http://localhost:8888/notebooks/acquire.ipynb',
#        'https://python.zach.lol/api/v1/sales?page=3',
#        'https://ds.codeup.com/8.3_Acquire/', 'https://python.zach.lol/',
#        'https://python.zach.lol/api/v1/items',
# ...

# %%
df.groupby(['ip']).count()
# Out:
#                  code  method   path  protocol   size  timestamp  unknown  \
# ip
# 173.173.113.51   1059    1059   1059      1059   1059       1059     1059
# 24.26.242.9        21      21     21        21     21         21       21
# 3.88.129.158        1       1      1         1      1          1        1
# 3.92.201.136        1       1      1         1      1          1        1
# 34.207.64.242       1       1      1         1      1          1        1
# 34.229.70.250       1       1      1         1      1          1        1
# 35.174.209.2        1       1      1         1      1          1        1
# 35.175.171.137      2       2      2         2      2          2        2
# 45.23.250.16        1       1      1         1      1          1        1
# 52.87.230.102       2       2      2         2      2          2        2
# 52.90.165.200       1       1      1         1      1          1        1
# 52.91.30.150        1       1      1         1      1          1        1
# ...

# %%
df.drop(['unknown'], axis=1, inplace=True)

# %%
# df.where(df.ip=='3.92.201.136')
df.loc[df['ip'] == '3.92.201.136']
# Out:
#     code            ip method path  protocol size           timestamp  \
# 223  200  3.92.201.136    GET    /  HTTP/1.1   42 2019-04-16 19:39:14
#
#                                             user_agent
# 223  Slackbot-LinkExpanding 1.0 (+https://api.slack...

# %%
df.shape
# Out:
# (13972, 9)

# %%
df.set_index('timestamp', inplace=True)

# %%
df.head()
# Out:
#                     code            ip method                   path  \
# timestamp
# 2019-04-16 19:34:42  200  97.105.19.58    GET  /api/v1/sales?page=81
# 2019-04-16 19:34:42  200  97.105.19.58    GET          /api/v1/items
# 2019-04-16 19:34:44  200  97.105.19.58    GET  /api/v1/sales?page=82
# 2019-04-16 19:34:46  200  97.105.19.58    GET  /api/v1/sales?page=83
# 2019-04-16 19:34:48  200  97.105.19.58    GET  /api/v1/sales?page=84
#
#                      protocol    size              user_agent
# timestamp
# 2019-04-16 19:34:42  HTTP/1.1  512495  python-requests/2.21.0
# 2019-04-16 19:34:42  HTTP/1.1    3561  python-requests/2.21.0
# 2019-04-16 19:34:44  HTTP/1.1  510103  python-requests/2.21.0
# 2019-04-16 19:34:46  HTTP/1.1  510003  python-requests/2.21.0
# 2019-04-16 19:34:48  HTTP/1.1  511963  python-requests/2.21.0

# %%
df['2019-04-16 19':'2019-04-16 21']
# Out:
#                     code            ip method                    path  \
# timestamp
# 2019-04-16 19:34:42  200  97.105.19.58    GET   /api/v1/sales?page=81
# 2019-04-16 19:34:42  200  97.105.19.58    GET           /api/v1/items
# 2019-04-16 19:34:44  200  97.105.19.58    GET   /api/v1/sales?page=82
# 2019-04-16 19:34:46  200  97.105.19.58    GET   /api/v1/sales?page=83
# 2019-04-16 19:34:48  200  97.105.19.58    GET   /api/v1/sales?page=84
# 2019-04-16 19:34:48  200  97.105.19.58    GET          /api/v1/stores
# 2019-04-16 19:34:50  200  97.105.19.58    GET   /api/v1/sales?page=85
# 2019-04-16 19:34:52  200  97.105.19.58    GET   /api/v1/sales?page=86
# 2019-04-16 19:34:52  200  97.105.19.58    GET                       /
# 2019-04-16 19:34:53  200  97.105.19.58    GET           /api/v1/items
# 2019-04-16 19:34:53  200  97.105.19.58    GET    /api/v1/items?page=2
# 2019-04-16 19:34:53  200  97.105.19.58    GET    /api/v1/items?page=3
# ...

# %%
df['size'] = df['size'].astype('int')

# %%
df['size'].resample('5min').sum()/1024/1024
# Out:
# timestamp
# 2019-04-16 19:30:00      4.871903
# 2019-04-16 19:35:00    104.507389
# 2019-04-16 19:40:00    141.070844
# 2019-04-16 19:45:00    222.858837
# 2019-04-16 19:50:00    242.591396
# 2019-04-16 19:55:00    239.019255
# 2019-04-16 20:00:00    239.787979
# 2019-04-16 20:05:00    185.740812
# 2019-04-16 20:10:00    138.732821
# 2019-04-16 20:15:00     42.956345
# 2019-04-16 20:20:00    131.335369
# 2019-04-16 20:25:00    105.799081
# 2019-04-16 20:30:00     95.956763
# 2019-04-16 20:35:00    209.596551
# 2019-04-16 20:40:00    235.559511
# 2019-04-16 20:45:00    241.736423
# 2019-04-16 20:50:00    236.222543
# 2019-04-16 20:55:00    133.694825
# 2019-04-16 21:00:00     83.060745
# 2019-04-16 21:05:00    130.294139
# 2019-04-16 21:10:00     84.047790
# 2019-04-16 21:15:00    102.875535
# 2019-04-16 21:20:00     64.522262
# 2019-04-16 21:25:00    111.954267
# 2019-04-16 21:30:00     94.939240
# 2019-04-16 21:35:00    216.027180
# 2019-04-16 21:40:00    150.819674
# ...

# %%
df = df.tz_localize('utc').tz_convert('America/Chicago').head()

# %%
df.head()
# Out:
#                           code            ip method                   path  \
# timestamp
# 2019-04-16 14:34:42-05:00  200  97.105.19.58    GET  /api/v1/sales?page=81
# 2019-04-16 14:34:42-05:00  200  97.105.19.58    GET          /api/v1/items
# 2019-04-16 14:34:44-05:00  200  97.105.19.58    GET  /api/v1/sales?page=82
# 2019-04-16 14:34:46-05:00  200  97.105.19.58    GET  /api/v1/sales?page=83
# 2019-04-16 14:34:48-05:00  200  97.105.19.58    GET  /api/v1/sales?page=84
#
#                            protocol    size              user_agent
# timestamp
# 2019-04-16 14:34:42-05:00  HTTP/1.1  512495  python-requests/2.21.0
# 2019-04-16 14:34:42-05:00  HTTP/1.1    3561  python-requests/2.21.0
# 2019-04-16 14:34:44-05:00  HTTP/1.1  510103  python-requests/2.21.0
# 2019-04-16 14:34:46-05:00  HTTP/1.1  510003  python-requests/2.21.0
# 2019-04-16 14:34:48-05:00  HTTP/1.1  511963  python-requests/2.21.0
