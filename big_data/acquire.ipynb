# %% [markdown]
# # Exercise
#
# Using case.csv & dept.csv:
# 1. read into spark environment (df_case, df_dept)
# 2. write df_case and df_dept back to disk into their own directories (my_cases and my_depts)
# 3. Write df_case and df_dept to parquet files (my_cases_parquet and my_depts_parquet)
# 4. Read your parquet files back into your spark environment.
# 5. Read case.csv and dept.csv into a pandas dataframe. (cases_pdf, depts_pdf)
# 6. Convert the pandas dataframes into spark dataframes (cases_sdf, depts_sdf)
# 7. Convert the spark dataframes back into pandas dataframes. (cases_pdf1, depts_pdf1)
# 8. Write the spark dataframes (cases_sdf, depts_sdf) to Hive tables.
# 9. Explore the Hive database/tables you have created using the methods in the lesson.
# 10. Read from the tables into two spark dataframes (cases_sdf, depts_sdf)

# %%
import pyspark

import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.types import *
import uuid   # Create unique table name

# %%
spark = SparkSession.builder.master("local").appName("read").\
    enableHiveSupport().\
    getOrCreate()

# %%
df_case = spark.read.csv("sa311/case.csv", sep=",",
                    header=True, inferSchema=True)
df_dept = spark.read.csv("sa311/dept.csv", sep=",",
                    header=True, inferSchema=True)

# %%
df_case.toPandas()
# Out:
#            case_id case_opened_date case_closed_date    SLA_due_date  \
# 0       1014127332      1/1/18 0:42     1/1/18 12:29    9/26/20 0:42
# 1       1014127333      1/1/18 0:46      1/3/18 8:11     1/5/18 8:30
# 2       1014127334      1/1/18 0:48      1/2/18 7:57     1/5/18 8:30
# 3       1014127335      1/1/18 1:29      1/2/18 8:13    1/17/18 8:30
# 4       1014127336      1/1/18 1:34     1/1/18 13:29     1/1/18 4:34
# 5       1014127337      1/1/18 6:28     1/1/18 14:38    1/31/18 8:30
# 6       1014127338      1/1/18 6:57     1/2/18 15:32    1/17/18 8:30
# 7       1014127339      1/1/18 6:58     1/2/18 15:32    1/17/18 8:30
# 8       1014127340      1/1/18 6:58     1/2/18 15:32    1/17/18 8:30
# 9       1014127341      1/1/18 6:59     1/2/18 15:32    1/17/18 8:30
# 10      1014127342      1/1/18 7:00     1/2/18 15:32    1/17/18 8:30
# 11      1014127343      1/1/18 7:02     1/2/18 15:32    1/17/18 8:30
# 12      1014127344      1/1/18 7:02     1/2/18 15:33    1/17/18 8:30
# 13      1014127345      1/1/18 7:03     1/2/18 15:32    1/17/18 8:30
# 14      1014127346      1/1/18 7:04     1/2/18 15:33    1/17/18 8:30
# 15      1014127347      1/1/18 7:04     1/2/18 15:33    1/17/18 8:30
# 16      1014127348      1/1/18 7:05     1/2/18 15:33    1/17/18 8:30
# 17      1014127349      1/1/18 7:06     1/2/18 15:33    1/17/18 8:30
# 18      1014127350      1/1/18 7:06     1/2/18 15:33    1/17/18 8:30
# 19      1014127351      1/1/18 7:07     1/2/18 15:33    1/17/18 8:30
# 20      1014127352      1/1/18 7:08     1/2/18 15:34    1/17/18 8:30
# 21      1014127353      1/1/18 7:08     1/2/18 15:34    1/17/18 8:30
# 22      1014127354      1/1/18 7:09     1/2/18 15:34    1/17/18 8:30
# 23      1014127355      1/1/18 7:10     1/2/18 15:35    1/17/18 8:30
# 24      1014127356      1/1/18 7:10     1/2/18 15:35    1/17/18 8:30
# 25      1014127357      1/1/18 7:11     1/2/18 15:35    1/17/18 8:30
# 26      1014127358      1/1/18 7:12     1/2/18 15:35    1/17/18 8:30
# 27      1014127359      1/1/18 7:12     1/2/18 15:35    1/17/18 8:30
# 28      1014127360      1/1/18 7:13     1/2/18 15:35    1/17/18 8:30
# 29      1014127361      1/1/18 7:13     1/2/18 15:35    1/17/18 8:30
# ...            ...              ...              ...             ...
# 841674  1014127274   12/31/17 18:43    3/19/18 20:29    1/5/18 18:43
# 841675  1014127275   12/31/17 18:44   12/31/17 21:22  12/31/17 21:44
# 841676  1014127277   12/31/17 18:48      1/3/18 9:26    1/5/18 18:48
# 841677  1014127278   12/31/17 18:54   12/31/17 21:27    1/5/18 18:54
# 841678  1014127281   12/31/17 19:03   12/31/17 19:08   9/25/20 19:03
# 841679  1014127283   12/31/17 19:08   12/31/17 22:03  12/31/17 22:08
# 841680  1014127285   12/31/17 19:19     2/3/18 22:00    1/5/18 19:19
# 841681  1014127288   12/31/17 19:33     2/11/18 6:49    1/5/18 19:33
# 841682  1014127290   12/31/17 19:37      1/4/18 8:46    1/5/18 19:37
# 841683  1014127291   12/31/17 19:39   12/31/17 20:23     1/3/18 8:30
# 841684  1014127292   12/31/17 19:41     4/3/18 14:55    1/5/18 19:41
# 841685  1014127293   12/31/17 19:42      1/1/18 6:33     1/1/18 7:42
# 841686  1014127295   12/31/17 19:46   12/31/17 19:52   9/25/20 19:46
# 841687  1014127299   12/31/17 19:50   12/31/17 19:58  12/31/17 22:50
# 841688  1014127301   12/31/17 19:57   12/31/17 21:26  12/31/17 22:57
# 841689  1014127303   12/31/17 20:32     2/3/18 21:37    1/5/18 20:32
# 841690  1014127305   12/31/17 20:46     1/2/18 16:00     1/1/18 8:46
# 841691  1014127311   12/31/17 21:00     2/6/18 16:11     3/7/18 8:30
# 841692  1014127312   12/31/17 21:07   12/31/17 21:12     1/1/18 0:07
# 841693  1014127314   12/31/17 21:28    2/11/18 16:05    1/5/18 21:28
# 841694  1014127316   12/31/17 21:33   12/31/17 22:51     1/3/18 8:30
# 841695  1014127320   12/31/17 21:59    3/19/18 14:17    1/5/18 21:59
# 841696  1014127321   12/31/17 21:59     1/1/18 10:51     1/3/18 8:30
# 841697  1014127322   12/31/17 22:04   12/31/17 22:09     1/1/18 1:04
# 841698  1014127323   12/31/17 22:04   12/31/17 22:32    1/1/18 10:04
# 841699  1014127325   12/31/17 22:23   12/31/17 22:34     1/3/18 8:30
# 841700  1014127326   12/31/17 22:26     1/1/18 20:29    1/1/18 10:26
# 841701  1014127327   12/31/17 22:27      1/1/18 9:56     1/3/18 8:30
# 841702  1014127329   12/31/17 22:41    3/19/18 20:33    1/5/18 22:41
# 841703  1014127331   12/31/17 22:44     1/1/18 11:14    1/5/18 22:44
#
#        case_late  num_days_late case_closed     dept_division  \
# 0             NO    -998.508762         YES  Field Operations
# 1             NO      -2.012604         YES       Storm Water
# 2             NO      -3.022338         YES       Storm Water
# 3             NO     -15.011481         YES  Code Enforcement
# 4            YES       0.372164         YES  Field Operations
# 5             NO     -29.743981         YES           Signals
# 6             NO     -14.706736         YES  Code Enforcement
# 7             NO     -14.706620         YES  Code Enforcement
# 8             NO     -14.706620         YES  Code Enforcement
# 9             NO     -14.706493         YES  Code Enforcement
# 10            NO     -14.706493         YES  Code Enforcement
# 11            NO     -14.706366         YES  Code Enforcement
# 12            NO     -14.706250         YES  Code Enforcement
# 13            NO     -14.706366         YES  Code Enforcement
# 14            NO     -14.706238         YES  Code Enforcement
# 15            NO     -14.705891         YES  Code Enforcement
# 16            NO     -14.706007         YES  Code Enforcement
# 17            NO     -14.705764         YES  Code Enforcement
# 18            NO     -14.705764         YES  Code Enforcement
# 19            NO     -14.705648         YES  Code Enforcement
# 20            NO     -14.705405         YES  Code Enforcement
# 21            NO     -14.705521         YES  Code Enforcement
# 22            NO     -14.704942         YES  Code Enforcement
# 23            NO     -14.704815         YES  Code Enforcement
# 24            NO     -14.704815         YES  Code Enforcement
# 25            NO     -14.704699         YES  Code Enforcement
# 26            NO     -14.704699         YES  Code Enforcement
# 27            NO     -14.704572         YES  Code Enforcement
# 28            NO     -14.704572         YES  Code Enforcement
# 29            NO     -14.704340         YES  Code Enforcement
# ...          ...            ...         ...               ...
# 841674       YES      73.073021         YES  Field Operations
# 841675        NO      -0.015694         YES  Field Operations
# 841676        NO      -2.390127         YES  Field Operations
# 841677        NO      -4.893750         YES  Field Operations
# 841678        NO    -998.995949         YES  Field Operations
# 841679        NO      -0.003299         YES  Field Operations
# 841680       YES      29.111794         YES  Field Operations
# 841681       YES      36.469630         YES  Field Operations
# 841682        NO      -1.452627         YES  Field Operations
# 841683        NO      -2.504387         YES           Signals
# 841684       YES      87.801667         YES  Field Operations
# 841685        NO      -0.048310         YES  Field Operations
# 841686        NO    -998.995856         YES  Field Operations
# 841687        NO      -0.119606         YES  Field Operations
# 841688        NO      -0.063067         YES  Field Operations
# 841689       YES      29.044942         YES  Field Operations
# 841690       YES       1.301238         YES  Field Operations
# 841691        NO     -28.679803         YES  Code Enforcement
# 841692        NO      -0.121493         YES  Field Operations
# 841693       YES      36.775475         YES  Field Operations
# 841694        NO      -2.401516         YES           Signals
# 841695       YES      72.679410         YES  Field Operations
# 841696        NO      -1.901806         YES           Signals
# 841697        NO      -0.121713         YES  Field Operations
# 841698        NO      -0.481019         YES  Field Operations
# 841699        NO      -2.413681         YES           Signals
# 841700       YES       0.418773         YES  Field Operations
# 841701        NO      -1.939688         YES           Signals
# 841702       YES      72.911493         YES  Field Operations
# 841703        NO      -4.478935         YES  Field Operations
#
#                                   service_request_type    SLA_days  \
# 0                                         Stray Animal  999.000000
# 1                               Removal Of Obstruction    4.322222
# 2                               Removal Of Obstruction    4.320729
# 3                           Front Or Side Yard Parking   16.291887
# 4                             Animal Cruelty(Critical)    0.125000
# 5                   Traffic Signal Ops and Maintenance   30.084468
# 6                           Front Or Side Yard Parking   16.064294
# 7                           Front Or Side Yard Parking   16.063796
# 8                    Right Of Way/Sidewalk Obstruction   16.063333
# 9                           Front Or Side Yard Parking   16.062859
# 10                          Front Or Side Yard Parking   16.062373
# 11                   Right Of Way/Sidewalk Obstruction   16.061042
# 12                          Front Or Side Yard Parking   16.060590
# 13                          Front Or Side Yard Parking   16.060116
# 14                   Right Of Way/Sidewalk Obstruction   16.059537
# 15                          Front Or Side Yard Parking   16.059074
# 16                          Front Or Side Yard Parking   16.058646
# 17                   Right Of Way/Sidewalk Obstruction   16.058194
# 18                          Front Or Side Yard Parking   16.057755
# 19                          Front Or Side Yard Parking   16.057338
# 20                   Right Of Way/Sidewalk Obstruction   16.056910
# 21                          Front Or Side Yard Parking   16.056435
# 22                          Front Or Side Yard Parking   16.055949
# 23                   Right Of Way/Sidewalk Obstruction   16.055498
# 24                          Front Or Side Yard Parking   16.055000
# 25                          Front Or Side Yard Parking   16.054560
# 26                   Right Of Way/Sidewalk Obstruction   16.054063
# 27                          Front Or Side Yard Parking   16.053657
# 28                          Front Or Side Yard Parking   16.053206
# 29                   Right Of Way/Sidewalk Obstruction   16.052801
# ...                                                ...         ...
# 841674                                  Animal Neglect    5.000000
# 841675                        Animal Cruelty(Critical)    0.125000
# 841676                                  Animal Neglect    5.000000
# 841677                 Aggressive Animal(Non-Critical)    5.000000
# 841678                                    Stray Animal  999.000000
# 841679                        Animal Cruelty(Critical)    0.125000
# 841680                                  Animal Neglect    5.000000
# 841681                                  Animal Neglect    5.000000
# 841682                                  Animal Neglect    5.000000
# 841683  Traffic Signal Ops and Maintenance - Emergency    2.534965
# 841684                                  Animal Neglect    5.000000
# 841685                         Trapped/Confined Animal    0.500000
# 841686                                    Stray Animal  999.000000
# 841687                        Animal Cruelty(Critical)    0.125000
# 841688                        Injured Animal(Critical)    0.125000
# 841689                                  Animal Neglect    5.000000
# 841690                         Trapped/Confined Animal    0.500000
# 841691                                Brush Violations   65.478704
# 841692                        Animal Cruelty(Critical)    0.125000
# 841693                                  Animal Neglect    5.000000
# 841694  Traffic Signal Ops and Maintenance - Emergency    2.455787
# 841695                                  Animal Neglect    5.000000
# 841696  Traffic Signal Ops and Maintenance - Emergency    2.437963
# 841697                        Animal Cruelty(Critical)    0.125000
# 841698                         Trapped/Confined Animal    0.500000
# 841699  Traffic Signal Ops and Maintenance - Emergency    2.421319
# 841700                         Trapped/Confined Animal    0.500000
# 841701  Traffic Signal Ops and Maintenance - Emergency    2.418275
# 841702                                  Animal Neglect    5.000000
# 841703                                  Animal Neglect    5.000000
#
#        case_status     source_id                            request_address  \
# 0           Closed      svcCRMLS       2315  EL PASO ST, San Antonio, 78207
# 1           Closed      svcCRMSS        2215  GOLIAD RD, San Antonio, 78223
# 2           Closed      svcCRMSS      102  PALFREY ST W, San Antonio, 78223
# 3           Closed      svcCRMSS       114  LA GARDE ST, San Antonio, 78223
# 4           Closed      svcCRMSS      734  CLEARVIEW DR, San Antonio, 78228
# 5           Closed      svcCRMSS                   BANDERA RD and BRESNAHAN
# 6           Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 7           Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 8           Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 9           Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 10          Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 11          Closed      svcCRMSS   10133  FIGARO CANYON, San Antonio, 78251
# 12          Closed      svcCRMSS     10129  BOXING PASS, San Antonio, 78251
# 13          Closed      svcCRMSS     10129  BOXING PASS, San Antonio, 78251
# 14          Closed      svcCRMSS     10129  BOXING PASS, San Antonio, 78251
# 15          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 16          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 17          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 18          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 19          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 20          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 21          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 22          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 23          Closed      svcCRMSS      834  BARREL POINT, San Antonio, 78251
# 24          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# 25          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# 26          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# 27          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# 28          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# 29          Closed      svcCRMSS      837  BARREL POINT, San Antonio, 78251
# ...            ...           ...                                        ...
# 841674      Closed        139345        7585  INGRAM RD, San Antonio, 78251
# 841675      Closed       dc12381     9011  WISDOM RIDGE, San Antonio, 78252
# 841676      Closed        120752            643  SUMNER, San Antonio, 78209
# 841677      Closed        139345         314  ASHLEY RD, San Antonio, 78221
# 841678      Closed        120752       2151  36TH ST SW, San Antonio, 78237
# 841679      Closed      svcCRMSS      207  COVINGTON RD, San Antonio, 78220
# 841680      Closed        120752     2910  OLD RANCH RD, San Antonio, 78217
# 841681      Closed        139345  12727  VISTA DEL NORT, San Antonio, 78216
# 841682      Closed        120752          1610  LEANDER, San Antonio, 78251
# 841683      Closed  CRM_Listener                     BUCKEYE and FREDSBG RD
# 841684      Closed        139345      230  SAN ROMAN DR, San Antonio, 78213
# 841685      Closed        120752      6318  ECHO CANYON, San Antonio, 78249
# 841686      Closed        120752        4907  HILL MIST, San Antonio, 78240
# 841687      Closed      svcCRMSS           928  LEAL ST, San Antonio, 78207
# 841688      Closed        120752     1518  SWAYING OAKS, San Antonio, 78227
# 841689      Closed        139345           1202  CLOWER, San Antonio, 78201
# 841690      Closed        120752       6750  SHADOW RUN, San Antonio, 78250
# 841691      Closed      svcCRMSS      9549  STILLFOREST, San Antonio, 78250
# 841692      Closed      svcCRMSS                PALMETTO WAY and LEXI PETAL
# 841693      Closed        120752     454  SAN IGNACIO N, San Antonio, 78228
# 841694      Closed  CRM_Listener                   EXPO BLVD and HUEBNER RD
# 841695      Closed        120752      8111  RUSTIC PARK, San Antonio, 78240
# 841696      Closed  CRM_Listener                     BLANCO RD and SUMMIT W
# 841697      Closed      svcCRMSS        233  THEO AVE E, San Antonio, 78214
# 841698      Closed        139345      1  HAVEN FOR HOPE, San Antonio, 78207
# 841699      Closed        120752                  FLORES ST S and MARCH AVE
# 841700      Closed        139345    223  BRACKENRIDGE A, San Antonio, 78209
# 841701      Closed  CRM_Listener              COMMERCE ST W and ZARZAMORA N
# 841702      Closed        139345        5655  UTSA BLVD, San Antonio, 78249
# 841703      Closed        120752        124  REMOUNT DR, San Antonio, 78218
#
#         council_district
# 0                      5
# 1                      3
# 2                      3
# 3                      3
# 4                      7
# 5                      7
# 6                      4
# 7                      4
# 8                      4
# 9                      4
# 10                     4
# 11                     4
# 12                     4
# 13                     4
# 14                     4
# 15                     4
# 16                     4
# 17                     4
# 18                     4
# 19                     4
# 20                     4
# 21                     4
# 22                     4
# 23                     4
# 24                     4
# 25                     4
# 26                     4
# 27                     4
# 28                     4
# 29                     4
# ...                  ...
# 841674                 6
# 841675                 4
# 841676                 2
# 841677                 3
# 841678                 5
# 841679                 2
# 841680                10
# 841681                 9
# 841682                 6
# 841683                 1
# 841684                 1
# 841685                 8
# 841686                 8
# 841687                 1
# 841688                 6
# 841689                 1
# 841690                 6
# 841691                 6
# 841692                 0
# 841693                 5
# 841694                 8
# 841695                 7
# 841696                 1
# 841697                 3
# 841698                 5
# 841699                 3
# 841700                 2
# 841701                 5
# 841702                 8
# 841703                 2
#
# [841704 rows x 14 columns]

# %%
df = spark.read.format("csv").\
    option("sep", ",").\
    option("header", True).\
    option("inferSchema", True).\
    load("sa311/source.csv")

df.printSchema()
# Out:
# root
#  |-- source_id: string (nullable = true)
#  |-- source_username: string (nullable = true)

# %%
df.show()
# Out:
# +---------+--------------------+
# |source_id|     source_username|
# +---------+--------------------+
# |   100137|    Merlene Blodgett|
# |   103582|         Carmen Cura|
# |   106463|     Richard Sanchez|
# |   119403|      Betty De Hoyos|
# |   119555|      Socorro Quiara|
# |   119868| Michelle San Miguel|
# |   120752|      Eva T. Kleiber|
# |   124405|           Lori Lara|
# |   132408|       Leonard Silva|
# |   135723|        Amy Cardenas|
# |   136202|    Michelle Urrutia|
# |   136979|      Leticia Garcia|
# |   137943|    Pamela K. Baccus|
# |   138605|        Marisa Ozuna|
# |   138650|      Kimberly Green|
# |   138650|Kimberly Green-Woods|
# |   138793| Guadalupe Rodriguez|
# |   138810|       Tawona Martin|
# |   139342|     Jessica Mendoza|
# |   139344|        Isis Mendoza|
# +---------+--------------------+
# only showing top 20 rows

# %%
schema = StructType([
    StructField("source_id", StringType()),
    StructField("source_username", StringType())
])

# %%
df_case.write.format('csv').mode("overwrite").\
    option("header","true").save("sa311/my_cases")

# %%
df_dept.write.format('csv').mode("overwrite").\
    option("header","true").save("sa311/my_depts")

# %%
df_case.write.format('parquet').mode('overwrite').\
    option('header','true').save('sa311/my_cases_parquet')

# %%
df_dept.write.format('parquet').mode('overwrite').\
    option('header','true').save('sa311/my_depts_parquet')

# %%
df_cases_parquet = spark.read.parquet("sa311/my_cases_parquet")
df_depts_parquet = spark.read.parquet("sa311/my_depts_parquet")

# %%
cases_pdf = pd.read_csv("sa311/case.csv", sep=",").dropna()
cases_pdf = cases_pdf.head()

# %%
depts_pdf = pd.read_csv("sa311/dept.csv", sep=",").dropna()
depts_pdf.head()
# Out:
#                    dept_division                  dept_name  \
# 0                311 Call Center           Customer Service
# 1                          Brush     Solid Waste Management
# 2                Clean and Green       Parks and Recreation
# 3  Clean and Green Natural Areas       Parks and Recreation
# 4               Code Enforcement  Code Enforcement Services
#
#   standardized_dept_name dept_subject_to_SLA
# 0       Customer Service                 YES
# 1            Solid Waste                 YES
# 2     Parks & Recreation                 YES
# 3     Parks & Recreation                 YES
# 4   DSD/Code Enforcement                 YES

# %%
cases_sdf = spark.createDataFrame(cases_pdf)
cases_sdf.show(5)
# Out:
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO| -2.012604167|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO| -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# |1014127335|     1/1/18 1:29|     1/2/18 8:13|1/17/18 8:30|       NO| -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|
# |1014127336|     1/1/18 1:34|    1/1/18 13:29| 1/1/18 4:34|      YES|  0.372164352|        YES|Field Operations|Animal Cruelty(Cr...|      0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+

# %%
df_dept_pd.isnull().sum()
# Out:
# dept_division             0
# dept_name                 1
# standardized_dept_name    0
# dept_subject_to_SLA       0
# dtype: int64

# %%
depts_sdf = spark.createDataFrame(depts_pdf)
depts_sdf.show(5)
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 5 rows

# %%
cases_pdf1 = cases_sdf.toPandas()
cases_pdf1.head()
# Out:
#       case_id case_opened_date case_closed_date  SLA_due_date case_late  \
# 0  1014127332      1/1/18 0:42     1/1/18 12:29  9/26/20 0:42        NO
# 1  1014127333      1/1/18 0:46      1/3/18 8:11   1/5/18 8:30        NO
# 2  1014127334      1/1/18 0:48      1/2/18 7:57   1/5/18 8:30        NO
# 3  1014127335      1/1/18 1:29      1/2/18 8:13  1/17/18 8:30        NO
# 4  1014127336      1/1/18 1:34     1/1/18 13:29   1/1/18 4:34       YES
#
#    num_days_late case_closed     dept_division        service_request_type  \
# 0    -998.508762         YES  Field Operations                Stray Animal
# 1      -2.012604         YES       Storm Water      Removal Of Obstruction
# 2      -3.022338         YES       Storm Water      Removal Of Obstruction
# 3     -15.011481         YES  Code Enforcement  Front Or Side Yard Parking
# 4       0.372164         YES  Field Operations    Animal Cruelty(Critical)
#
#      SLA_days case_status source_id                        request_address  \
# 0  999.000000      Closed  svcCRMLS   2315  EL PASO ST, San Antonio, 78207
# 1    4.322222      Closed  svcCRMSS    2215  GOLIAD RD, San Antonio, 78223
# 2    4.320729      Closed  svcCRMSS  102  PALFREY ST W, San Antonio, 78223
# 3   16.291887      Closed  svcCRMSS   114  LA GARDE ST, San Antonio, 78223
# 4    0.125000      Closed  svcCRMSS  734  CLEARVIEW DR, San Antonio, 78228
#
#    council_district
# 0                 5
# 1                 3
# 2                 3
# 3                 3
# 4                 7

# %%
depts_pdf1 = depts_sdf.toPandas()
depts_pdf1.head()
# Out:
#                    dept_division                  dept_name  \
# 0                311 Call Center           Customer Service
# 1                          Brush     Solid Waste Management
# 2                Clean and Green       Parks and Recreation
# 3  Clean and Green Natural Areas       Parks and Recreation
# 4               Code Enforcement  Code Enforcement Services
#
#   standardized_dept_name dept_subject_to_SLA
# 0       Customer Service                 YES
# 1            Solid Waste                 YES
# 2     Parks & Recreation                 YES
# 3     Parks & Recreation                 YES
# 4   DSD/Code Enforcement                 YES

# %%
cases_table = "df_" + str(uuid.uuid4().hex)  
cases_sdf.write.saveAsTable(cases_table)

# %%
depts_table = "df_" + str(uuid.uuid4().hex)  
depts_sdf.write.saveAsTable(depts_table)

# %%
query = "DESCRIBE %s" % cases_table
spark.sql(query).show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |             case_id|   bigint|   null|
# |    case_opened_date|   string|   null|
# |    case_closed_date|   string|   null|
# |        SLA_due_date|   string|   null|
# |           case_late|   string|   null|
# |       num_days_late|   double|   null|
# |         case_closed|   string|   null|
# |       dept_division|   string|   null|
# |service_request_type|   string|   null|
# |            SLA_days|   double|   null|
# |         case_status|   string|   null|
# |           source_id|   string|   null|
# |     request_address|   string|   null|
# |    council_district|   bigint|   null|
# +--------------------+---------+-------+

# %%
query = "DESCRIBE %s" % depts_table
spark.sql(query).show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |       dept_division|   string|   null|
# |           dept_name|   string|   null|
# |standardized_dept...|   string|   null|
# | dept_subject_to_SLA|   string|   null|
# +--------------------+---------+-------+

# %% [markdown]
# 10. Read from the tables into two spark dataframes (cases_sdf, depts_sdf)

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +------------+
# |databaseName|
# +------------+
# |     default|
# +------------+

# %%
spark.sql("USE default")
spark.sql("SHOW TABLES").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|df_2216a1f6aa8848...|      false|
# | default|df_4c5a61b1ed834b...|      false|
# | default|df_6eb0c9bf0d1c4d...|      false|
# | default|df_d9e46cf4b15249...|      false|
# | default|df_ea8e6cd5a9fb46...|      false|
# +--------+--------------------+-----------+

# %%
spark.sql(f"DESCRIBE {cases_table}").show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |             case_id|   bigint|   null|
# |    case_opened_date|   string|   null|
# |    case_closed_date|   string|   null|
# |        SLA_due_date|   string|   null|
# |           case_late|   string|   null|
# |       num_days_late|   double|   null|
# |         case_closed|   string|   null|
# |       dept_division|   string|   null|
# |service_request_type|   string|   null|
# |            SLA_days|   double|   null|
# |         case_status|   string|   null|
# |           source_id|   string|   null|
# |     request_address|   string|   null|
# |    council_district|   bigint|   null|
# +--------------------+---------+-------+

# %%
spark.sql(f"SELECT * FROM {depts_table} LIMIT 10").show()
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Dangerous Premise...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Director's Office...|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |          District 1|        City Council|          City Council|                 NO|
# +--------------------+--------------------+----------------------+-------------------+

# %%
cases_sdf1 = spark.sql(f"SELECT * FROM {cases_table}")
cases_sdf1.show(5)
# Out:
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO| -2.012604167|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO| -3.022337963|        YES|     Storm Water|Removal Of Obstru...|4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# |1014127335|     1/1/18 1:29|     1/2/18 8:13|1/17/18 8:30|       NO| -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|
# |1014127336|     1/1/18 1:34|    1/1/18 13:29| 1/1/18 4:34|      YES|  0.372164352|        YES|Field Operations|Animal Cruelty(Cr...|      0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|
# +----------+----------------+----------------+------------+---------+-------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+

# %%
depts_sdf1 = spark.sql(f"SELECT * FROM {depts_table}")
depts_sdf1.show(5)
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 5 rows
